# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from evidently import ColumnMapping
from evidently.test_suite import TestSuite
from evidently.test_preset import DataStabilityTestPreset

from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, DataQualityPreset, ClassificationPreset
import warnings
warnings.filterwarnings('ignore')
print("Hello world")
# Out:
# Hello world

# %%
ref_data = pd.read_csv("../data/processed/preprocessed.csv")
cur_data = pd.read_csv("../data/processed/test.csv")

# %%
ref_data['Machine failure'].value_counts()
# Out:
# Machine failure
# 1    38617
# 0    19295
# Name: count, dtype: int64

# %%
ref_X = ref_data.drop(["Machine failure", "type_of_failure"], axis=1)
ref_y = ref_data["Machine failure"]

cur_X = cur_data.drop(["Machine failure", "type_of_failure"], axis=1)
cur_y = cur_data["Machine failure"]

# %%
ref_X_train, ref_X_test, ref_y_train, ref_y_test = train_test_split(ref_X, ref_y, test_size=0.2, random_state=42)

# %%
ref_y_test
# Out:
# 16971    1
# 53134    1
# 46497    0
# 9584     0
# 1566     0
#         ..
# 32887    1
# 35872    1
# 4623     0
# 6231     0
# 40380    0
# Name: Machine failure, Length: 11583, dtype: int64

# %%
cur_X
# Out:
#        Type  Rotational speed [rpm]  Torque [Nm]  Tool wear [min]
# 0       0.0                0.131497     0.747326         0.749753  \
# 1       0.0                0.254873     0.386470         0.870363
# 2       0.0                0.159291     0.550137         0.823704
# 3       2.0                0.175786     0.542582         0.241107
# 4       0.0                0.201615     0.447002         0.848406
# ...     ...                     ...          ...              ...
# 11578   0.0                0.840343     0.112007         0.431981
# 11579   0.0                0.411326     0.267356         0.888804
# 11580   1.0                0.412889     0.268972         0.874461
# 11581   0.0                0.296275     0.310440         0.577075
# 11582   0.0                0.169226     0.518524         0.863894
#
#        Air temperature [c]  Process temperature [c]
# 0                 0.621506                 0.653219
# 1                 0.554348                 0.664579
# 2                 0.710039                 0.646151
# 3                 0.315217                 0.382716
# 4                 0.873713                 0.761418
# ...                    ...                      ...
# 11578             0.308726                 0.286695
# 11579             0.465331                 0.433503
# 11580             0.467391                 0.466927
# 11581             0.206522                 0.333333
# 11582             0.249876                 0.347770
#
# [11583 rows x 6 columns]

# %%
ref_y.value_counts()
# Out:
# Machine failure
# 1    38617
# 0    19295
# Name: count, dtype: int64

# %%
rf = RandomForestClassifier()
rf.fit(ref_X_train.values, ref_y_train.values)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Using predict

# %%
ref_pred = rf.predict(ref_X_test)
ref_pred = pd.DataFrame(ref_pred, columns=["Prediction"])
cur_pred = rf.predict(cur_X)
cur_pred = pd.DataFrame(cur_pred, columns=["Prediction"])

# %%
ref_X_test.reset_index(inplace=True, drop=True)
ref_y_test.reset_index(inplace=True, drop=True)
ref_merged = pd.concat([ref_X_test, ref_y_test], axis=1)
ref_merged = pd.concat([ref_merged, ref_pred], axis=1)
ref_merged
# Out:
#        Type  Rotational speed [rpm]  Torque [Nm]  Tool wear [min]
# 0       0.0                0.108726     0.607490         0.640992  \
# 1       2.0                0.122930     0.613913         0.964756
# 2       0.0                0.195818     0.573143         0.572728
# 3       0.0                0.210128     0.515110         0.067194
# 4       1.0                0.136787     0.563187         0.584980
# ...     ...                     ...          ...              ...
# 11578   1.0                0.819950     0.122083         0.334225
# 11579   0.0                0.095867     0.851640         0.000000
# 11580   0.0                0.207800     0.506868         0.707510
# 11581   1.0                0.190338     0.508242         0.584980
# 11582   0.0                0.184044     0.468135         0.739213
#
#        Air temperature [c]  Process temperature [c]  Machine failure
# 0                 0.752546                 0.613613                1  \
# 1                 0.576635                 0.461772                1
# 2                 0.364513                 0.510378                0
# 3                 0.434783                 0.592593                0
# 4                 0.293478                 0.296296                0
# ...                    ...                      ...              ...
# 11578             0.568599                 0.537018                1
# 11579             0.682132                 0.629166                1
# 11580             0.836957                 0.666667                0
# 11581             0.652174                 0.654321                0
# 11582             0.632473                 0.698688                0
#
#        Prediction
# 0               1
# 1               1
# 2               0
# 3               0
# 4               0
# ...           ...
# 11578           1
# 11579           1
# 11580           0
# 11581           0
# 11582           0
#
# [11583 rows x 8 columns]

# %%
cur_X.reset_index(inplace=True, drop=True)
cur_y.reset_index(inplace=True, drop=True)
cur_merged = pd.concat([cur_X, cur_y], axis=1)
cur_merged = pd.concat([cur_merged, cur_pred], axis=1)
cur_merged
# Out:
#        Type  Rotational speed [rpm]  Torque [Nm]  Tool wear [min]
# 0       0.0                0.131497     0.747326         0.749753  \
# 1       0.0                0.254873     0.386470         0.870363
# 2       0.0                0.159291     0.550137         0.823704
# 3       2.0                0.175786     0.542582         0.241107
# 4       0.0                0.201615     0.447002         0.848406
# ...     ...                     ...          ...              ...
# 11578   0.0                0.840343     0.112007         0.431981
# 11579   0.0                0.411326     0.267356         0.888804
# 11580   1.0                0.412889     0.268972         0.874461
# 11581   0.0                0.296275     0.310440         0.577075
# 11582   0.0                0.169226     0.518524         0.863894
#
#        Air temperature [c]  Process temperature [c]  Machine failure
# 0                 0.621506                 0.653219                1  \
# 1                 0.554348                 0.664579                1
# 2                 0.710039                 0.646151                1
# 3                 0.315217                 0.382716                0
# 4                 0.873713                 0.761418                1
# ...                    ...                      ...              ...
# 11578             0.308726                 0.286695                1
# 11579             0.465331                 0.433503                1
# 11580             0.467391                 0.466927                1
# 11581             0.206522                 0.333333                0
# 11582             0.249876                 0.347770                1
#
#        Prediction
# 0               1
# 1               1
# 2               1
# 3               0
# 4               1
# ...           ...
# 11578           1
# 11579           1
# 11580           1
# 11581           0
# 11582           1
#
# [11583 rows x 8 columns]

# %%
cm = ColumnMapping()
cm.target = "Machine failure"
cm.prediction = "Prediction"
cm.target_names = ["No Failure", "Machine Failure"]

# %%
classification_performance_report = Report(metrics=[
    ClassificationPreset(),
])
classification_performance_report.run(reference_data=ref_merged, current_data=cur_merged, column_mapping = cm)
classification_performance_report.save_html("../reports/classification_performance_report.html")

# %% [markdown]
# ## Using Probas

# %%
ref_probas = pd.DataFrame(rf.predict_proba(ref_X_test))
ref_probas.columns = ['No Failure', 'Machine Failure']
cur_probas = pd.DataFrame(rf.predict_proba(cur_X))
cur_probas.columns = ['No Failure', 'Machine Failure']

# %%
ref_probas = pd.DataFrame(rf.predict_proba(ref_X_test))
ref_probas.columns = ['No Failure', 'Machine Failure']
cur_probas = pd.DataFrame(rf.predict_proba(cur_X))
cur_probas.columns = ['No Failure', 'Machine Failure']

# %%
ref_probas
# Out:
#        No Failure  Machine Failure
# 0            0.00             1.00
# 1            0.05             0.95
# 2            1.00             0.00
# 3            1.00             0.00
# 4            1.00             0.00
# ...           ...              ...
# 11578        0.00             1.00
# 11579        0.01             0.99
# 11580        0.99             0.01
# 11581        1.00             0.00
# 11582        1.00             0.00
#
# [11583 rows x 2 columns]

# %%
ref_probas.value_counts()
# Out:
# No Failure  Machine Failure
# 0.00        1.00               5995
# 1.00        0.00               3064
# 0.01        0.99                937
# 0.99        0.01                359
# 0.02        0.98                322
#                                ...
# 0.68        0.32                  1
# 0.46        0.54                  1
# 0.55        0.45                  1
# 0.48        0.52                  1
# 0.67        0.33                  1
# Name: count, Length: 99, dtype: int64

# %%
ref_X_test.reset_index(inplace=True, drop=True)
ref_X_test['Attrition'] = ['No Failure' if x == 0 else 'Machine Failure' for x in ref_y_test]
ref_merged = pd.concat([ref_X_test, ref_probas], axis = 1)

cur_X.reset_index(inplace=True, drop=True)
cur_X['Attrition'] = ['No Failure' if x == 0 else 'Machine Failure' for x in cur_y]
cur_merged = pd.concat([cur_X, cur_probas], axis = 1)

# %%
ref_merged
# Out:
#        Type  Rotational speed [rpm]  Torque [Nm]  Tool wear [min]
# 0       0.0                0.108726     0.607490         0.640992  \
# 1       2.0                0.122930     0.613913         0.964756
# 2       0.0                0.195818     0.573143         0.572728
# 3       0.0                0.210128     0.515110         0.067194
# 4       1.0                0.136787     0.563187         0.584980
# ...     ...                     ...          ...              ...
# 11578   1.0                0.819950     0.122083         0.334225
# 11579   0.0                0.095867     0.851640         0.000000
# 11580   0.0                0.207800     0.506868         0.707510
# 11581   1.0                0.190338     0.508242         0.584980
# 11582   0.0                0.184044     0.468135         0.739213
#
#        Air temperature [c]  Process temperature [c]        Attrition
# 0                 0.752546                 0.613613  Machine Failure  \
# 1                 0.576635                 0.461772  Machine Failure
# 2                 0.364513                 0.510378       No Failure
# 3                 0.434783                 0.592593       No Failure
# 4                 0.293478                 0.296296       No Failure
# ...                    ...                      ...              ...
# 11578             0.568599                 0.537018  Machine Failure
# 11579             0.682132                 0.629166  Machine Failure
# 11580             0.836957                 0.666667       No Failure
# 11581             0.652174                 0.654321       No Failure
# 11582             0.632473                 0.698688       No Failure
#
#        No Failure  Machine Failure
# 0            0.00             1.00
# 1            0.05             0.95
# 2            1.00             0.00
# 3            1.00             0.00
# 4            1.00             0.00
# ...           ...              ...
# 11578        0.00             1.00
# 11579        0.01             0.99
# 11580        0.99             0.01
# 11581        1.00             0.00
# 11582        1.00             0.00
#
# [11583 rows x 9 columns]

# %%
cm  = ColumnMapping()
cm.target = 'Attrition'
cm.prediction = ['No Failure', 'Machine Failure']
cm.pos_label = 'No Failure'

# %%
classification_performance_report = Report(metrics=[
    ClassificationPreset(),
])

classification_performance_report.run(reference_data=ref_merged, current_data=cur_merged, column_mapping = cm)
classification_performance_report.save_html("../reports/classification_performance_report.html")
